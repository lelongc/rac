# %% [markdown]
# <a href="https://colab.research.google.com/github/lelongc/rac/blob/main/1c_gptsovits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Kết nối Google Drive để lấy model của sếp
from google.colab import drive
drive.mount('/content/drive')

# 2. Tải Source Code GPT-SoVITS mới nhất
# %cd /content
# !rm -rf GPT-SoVITS
# !git clone https://github.com/RVC-Boss/GPT-SoVITS.git

# 3. Ép Colab dùng Python 3.10 (Né lỗi Python 3.12) và cài FFmpeg
print("🚀 Đang thiết lập môi trường Python 3.10 siêu tốc...")
# !apt-get update -qq
# !apt-get install -y -qq python3.10 python3.10-dev python3.10-distutils ffmpeg > /dev/null
# !curl -s https://bootstrap.pypa.io/get-pip.py -o get-pip.py
# !python3.10 get-pip.py -q

# 4. Cài thư viện lõi (Cấm build thủ công để tiết kiệm thời gian)
print("📦 Đang nạp đạn thư viện (Tầm 1-2 phút)...")
# %cd /content/GPT-SoVITS
# !python3.10 -m pip install -q -U pip wheel setuptools
# !python3.10 -m pip install -q -r extra-req.txt
# !python3.10 -m pip install -q -r requirements.txt --prefer-binary

# 5. Kéo bộ não ngôn ngữ (Để không bị lỗi HFValidationError)
print("🧠 Đang tải bộ từ điển ngôn ngữ nền...")
# !mkdir -p GPT_SoVITS/pretrained_models
# !rm -rf GPT_SoVITS/pretrained_models/chinese-roberta-wwm-ext-large
# !rm -rf GPT_SoVITS/pretrained_models/chinese-hubert-base
# !git clone -q https://huggingface.co/hfl/chinese-roberta-wwm-ext-large GPT_SoVITS/pretrained_models/chinese-roberta-wwm-ext-large
# !git clone -q https://huggingface.co/TencentGameMate/chinese-hubert-base GPT_SoVITS/pretrained_models/chinese-hubert-base

print("✨ CÀI ĐẶT HOÀN TẤT! SẾP CHẠY Ô TIẾP THEO ĐỂ MỞ WEBUI NHÉ!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content
# Cloning into 'GPT-SoVITS'...
# remote: Enumerating objects: 5832, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 5832 (delta 15), reused 4 (delta 4), pack-reused 5803 (from 3)
# Receiving objects: 100% (5832/5832), 14.07 MiB | 14.03 MiB/s, done.
# Resolving deltas: 100% (3340/3340), done.
# 🚀 Đang thiết lập môi trường Python 3.10 siêu tốc...
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# 📦 Đang nạp đạn thư viện (Tầm 1-2 phút)...
# /content/GPT-SoVITS
# 🧠 Đang tải bộ từ điển ngôn ngữ nền...
# ✨ CÀI ĐẶT HOÀN TẤT! SẾP CHẠY Ô TIẾP THEO ĐỂ MỞ WEBUI NHÉ!

# %% [markdown]
# 2

# %%
import os

# 1. Di chuyển vào thư mục gốc
# %cd /content/GPT-SoVITS

# 2. Khai báo đường dẫn model Kurisu của sếp
gpt_model = "/content/drive/MyDrive/ggcl/kurisu/Kurisu_Models_Backup/kurisu-e15.ckpt"
sovits_model = "/content/drive/MyDrive/ggcl/kurisu/Kurisu_Models_Backup/kurisu_e15_s6000.pth"

# 3. Kiểm tra và tải nốt file SV (Nhận diện giọng nói) cho bản V2Pro nếu thiếu
sv_path = "GPT_SoVITS/pretrained_models/sv/pretrained_eres2netv2w24s4ep4.ckpt"
if not os.path.exists(sv_path):
    print("📥 Đang nạp nốt linh kiện nhận diện giọng nói V2Pro...")
    # !mkdir -p GPT_SoVITS/pretrained_models/sv
    # !wget -q -O {sv_path} https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/sv/pretrained_eres2netv2w24s4ep4.ckpt

# 4. Kiểm tra file của sếp có tồn tại không
if not os.path.exists(gpt_model):
    print(f"❌ KHÔNG TÌM THẤY FILE GPT: {gpt_model}")
elif not os.path.exists(sovits_model):
    print(f"❌ KHÔNG TÌM THẤY FILE SOVITS: {sovits_model}")
else:
    print(f"🎯 Đã khóa mục tiêu:\n- {gpt_model}\n- {sovits_model}")
    print("🚀 Đang mở cổng không gian (Public Link)...")

    # 5. Lệnh khởi động thần thánh: Ép Python 3.10 + Fix lỗi Backend + Bật Share Public
    # !is_share="True" MPLBACKEND=Agg gpt_path="{gpt_model}" sovits_path="{sovits_model}" PYTHONPATH=/content/GPT-SoVITS python3.10 GPT_SoVITS/inference_webui.py
# Out:
# /content/GPT-SoVITS
# 🎯 Đã khóa mục tiêu:
# - /content/drive/MyDrive/ggcl/kurisu/Kurisu_Models_Backup/kurisu-e15.ckpt
# - /content/drive/MyDrive/ggcl/kurisu/Kurisu_Models_Backup/kurisu_e15_s6000.pth
# 🚀 Đang mở cổng không gian (Public Link)...
# /usr/local/lib/python3.10/dist-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.0.1)/charset_normalizer (3.4.5) doesn't match a supported version!
#   warnings.warn(
# /content/drive/MyDrive/ggcl/kurisu/Kurisu_Models_Backup/kurisu_e15_s6000.pth v2 v2Pro False
# loading sovits_v2Pro <All keys matched successfully>
# Running on local URL:  http://0.0.0.0:9872
# Running on public URL: https://45e0a5be5cbbcdbf78.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# Keyboard interruption in main thread... closing server.
# Traceback (most recent call last):
# ...

# %%
import os

# 1. Tạo đúng cái "chuồng" V2Pro (Chữ P viết hoa mới chịu nha sếp)
# !mkdir -p /content/GPT-SoVITS/GPT_weights_v2Pro
# !mkdir -p /content/GPT-SoVITS/SoVITS_weights_v2Pro

# 2. Bế bả Kurisu từ Drive vào đúng chỗ V2Pro
print("🚚 Đang vận chuyển bả Kurisu vào khu vực V2Pro...")
# !cp "/content/drive/MyDrive/ggcl/kurisu/Kurisu_Models_Backup/kurisu-e15.ckpt" /content/GPT-SoVITS/GPT_weights_v2Pro/
# !cp "/content/drive/MyDrive/ggcl/kurisu/Kurisu_Models_Backup/kurisu_e15_s6000.pth" /content/GPT-SoVITS/SoVITS_weights_v2Pro/

# 3. Mở cổng không gian với chế độ V2Pro
# %cd /content/GPT-SoVITS
print("🚀 Mở WebUI... Sếp nhớ bấm 'refresh' ở 2 cái ô đầu tiên nhé!")

# !is_share="True" version="v2" MPLBACKEND=Agg \
PYTHONPATH=/content/GPT-SoVITS \
python3.10 GPT_SoVITS/inference_webui.py
# Out:
# 🚚 Đang vận chuyển bả Kurisu vào khu vực V2Pro...
# /content/GPT-SoVITS
# 🚀 Mở WebUI... Sếp nhớ bấm 'refresh' ở 2 cái ô đầu tiên nhé!
# /usr/local/lib/python3.10/dist-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.0.1)/charset_normalizer (3.4.5) doesn't match a supported version!
#   warnings.warn(
# SoVITS_weights_v2Pro/kurisu_e15_s6000.pth v2 v2Pro False
# loading sovits_v2Pro <All keys matched successfully>
# Running on local URL:  http://0.0.0.0:9872
# Running on public URL: https://c8006a060a30af4bc6.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# Actual Input Reference Text: 男の人に怖い顔で迫られて恐怖を感じちゃったりなんかしてないし、その後のあんたのバカゼリフにほっとして涙が出ちゃったわけでもないからな。
# Actual Input Target Text: べ、別にあなたの心配なんかしてないんだからね！ただ、ちょっと気になっただけよ！勘違いしないでよね、バカ！
# Actual Input Target Text (after sentence segmentation): べ、
# ...
