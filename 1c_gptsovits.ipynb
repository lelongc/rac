# %% [markdown]
# <a href="https://colab.research.google.com/github/lelongc/rac/blob/main/1c_gptsovits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Kết nối Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 2. Tải Source Code mới nhất
# %cd /content
# !rm -rf GPT-SoVITS
# !git clone https://github.com/RVC-Boss/GPT-SoVITS.git

# 3. Cài Python 3.10 và FFmpeg
print("🚀 Đang thiết lập môi trường Python 3.10...")
# !apt-get update -qq
# !apt-get install -y -qq python3.10 python3.10-dev python3.10-distutils ffmpeg > /dev/null
# !curl -s https://bootstrap.pypa.io/get-pip.py -o get-pip.py
# !python3.10 get-pip.py -q

# 4. Cài thư viện
print("📦 Đang nạp thư viện (Tầm 1-2 phút)...")
# %cd /content/GPT-SoVITS
# !python3.10 -m pip install -q -U pip wheel setuptools
# !python3.10 -m pip install -q -r extra-req.txt
# !python3.10 -m pip install -q -r requirements.txt --prefer-binary
# !python3.10 -m pip install -q fast-langdetect  # Cài thêm bản vá nhận diện ngôn ngữ

# 5. Tải các bộ não ngôn ngữ nền (Tránh lỗi HFValidationError)
print("🧠 Đang tải bộ từ điển nền...")
# !mkdir -p GPT_SoVITS/pretrained_models
# !git clone -q https://huggingface.co/hfl/chinese-roberta-wwm-ext-large GPT_SoVITS/pretrained_models/chinese-roberta-wwm-ext-large
# !git clone -q https://huggingface.co/TencentGameMate/chinese-hubert-base GPT_SoVITS/pretrained_models/chinese-hubert-base

print("✨ CÀI ĐẶT XONG! CHẠY Ô 2 ĐỂ GẶP KURISU!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content
# Cloning into 'GPT-SoVITS'...
# remote: Enumerating objects: 5832, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 5832 (delta 15), reused 4 (delta 4), pack-reused 5803 (from 3)
# Receiving objects: 100% (5832/5832), 14.07 MiB | 14.58 MiB/s, done.
# Resolving deltas: 100% (3340/3340), done.
# 🚀 Đang thiết lập môi trường Python 3.10...
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# 📦 Đang nạp thư viện (Tầm 1-2 phút)...
# /content/GPT-SoVITS
# 🧠 Đang tải bộ từ điển nền...
# ✨ CÀI ĐẶT XONG! CHẠY Ô 2 ĐỂ GẶP KURISU!

# %%
import os

# 1. Khai báo đường dẫn model từ Drive
gpt_drive = "/content/drive/MyDrive/ggcl/kurisu/Kurisu_Models_Backup/kurisu-e15.ckpt"
sovits_drive = "/content/drive/MyDrive/ggcl/kurisu/Kurisu_Models_Backup/kurisu_e15_s6000.pth"

# 2. Cài nốt cái "phụ tùng" dở hơi mà nó đang đòi
print("🛠️ Đang vá lỗi TorchCodec để đọc được file âm thanh...")
# !python3.10 -m pip install -q torchcodec

# 3. Tạo thư mục và copy model (như cũ)
# %cd /content/GPT-SoVITS
# !mkdir -p GPT_weights_v2Pro SoVITS_weights_v2Pro GPT_SoVITS/pretrained_models/sv GPT_SoVITS/pretrained_models/fast_langdetect
# !cp "{gpt_drive}" GPT_weights_v2Pro/
# !cp "{sovits_drive}" SoVITS_weights_v2Pro/

# 4. Tải file phụ trợ (nếu thiếu)
if not os.path.exists("GPT_SoVITS/pretrained_models/sv/pretrained_eres2netv2w24s4ep4.ckpt"):
    # !wget -q -O GPT_SoVITS/pretrained_models/sv/pretrained_eres2netv2w24s4ep4.ckpt https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/sv/pretrained_eres2netv2w24s4ep4.ckpt
if not os.path.exists("GPT_SoVITS/pretrained_models/fast_langdetect/lid.176.bin"):
    # !wget -q -O GPT_SoVITS/pretrained_models/fast_langdetect/lid.176.bin https://dl.fbaipublicfiles.com/fasttext/supervised-models/lid.176.bin

# 5. Mở cổng không gian
print("🚀 Đang mở lại WebUI... Lần này bả hết đường từ chối!")
os.environ["version"] = "v2"
os.environ["is_share"] = "True"

# !MPLBACKEND=Agg gpt_path="{gpt_drive}" sovits_path="{sovits_drive}" \
PYTHONPATH=/content/GPT-SoVITS \
python3.10 GPT_SoVITS/inference_webui.py
# Out:
# 🛠️ Đang vá lỗi TorchCodec để đọc được file âm thanh...
# /content/GPT-SoVITS
# 🚀 Đang mở lại WebUI... Lần này bả hết đường từ chối!
# /usr/local/lib/python3.10/dist-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.0.1)/charset_normalizer (3.4.5) doesn't match a supported version!
#   warnings.warn(
# /content/drive/MyDrive/ggcl/kurisu/Kurisu_Models_Backup/kurisu_e15_s6000.pth v2 v2Pro False
# loading sovits_v2Pro <All keys matched successfully>
# Running on local URL:  http://0.0.0.0:9872
# Running on public URL: https://133aed9d709c5f38ca.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# SoVITS_weights_v2Pro/kurisu_e15_s6000.pth v2 v2Pro False
# loading sovits_v2Pro <All keys matched successfully>
# Actual Input Reference Text: 男の人に怖い顔で迫られて恐怖を感じちゃったりなんかしてないし、その後のあんたのバカゼリフにほっとして涙が出ちゃったわけでもないからな。
# ...
