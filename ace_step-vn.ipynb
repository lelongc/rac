# %% [markdown]
# <a href="https://colab.research.google.com/github/lelongc/rac/blob/main/ace_step-vn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🎵 ACE-Step v1.5 - Google Colab Launcher
# ### 🔴 Brought to you by [AI With Chucky](https://youtube.com/@AIWithChucky)
#
# **Notes:**
# - This requires a GPU runtime (T4 is usually sufficient).
# - The first run will take a few minutes to download the models (approx 10GB).
# - **Wait for the link ending in `gradio.live` to appear at the bottom.**

# %%
# @title 1. Clone Repository & Patch Dependencies
import os
import sys

# 1. Clone the Hugging Face Space
if not os.path.exists("Ace-Step-v1.5"):
    print("Cloning ACE-Step v1.5 repository...")
    # !git clone https://huggingface.co/spaces/ACE-Step/Ace-Step-v1.5
else:
    print("Repository already exists.")

# 2. Force Change Directory
# This ensures subsequent commands run inside the folder
os.chdir("/content/Ace-Step-v1.5")
print(f"Working directory set to: {os.getcwd()}")

# 3. Patch requirements.txt
# The original file asks for torch>=2.9.1 (future version) for Linux, which fails install.
# We relax this to allow the current stable torch version.
print("Patching requirements.txt...")
# !sed -i 's/torch>=2.9.1/torch/g' requirements.txt

# 4. Patch app.py for Public Access
# By default, share=False. We change it to share=True to get a public Gradio link.
print("Patching app.py to enable public sharing...")
# !sed -i 's/share=False/share=True/g' app.py

print("✅ Setup phase 1 complete.")
# Out:
# Repository already exists.
# Working directory set to: /content/Ace-Step-v1.5
# Patching requirements.txt...
# Patching app.py to enable public sharing...
# ✅ Setup phase 1 complete.

# %%
# @title 2. Install Dependencies
import os

# Ensure we are in the correct folder
if os.getcwd() != "/content/Ace-Step-v1.5":
    os.chdir("/content/Ace-Step-v1.5")

print("Installing Python dependencies... (This may take 3-5 minutes)")

# Install dependencies with CUDA support
# We skip strict version checks for some libs to avoid Colab conflicts
# !pip install -r requirements.txt --extra-index-url https://download.pytorch.org/whl/cu121

# Install system dependency for audio processing
# !apt-get install -y ffmpeg

print("✅ Dependencies installed.")
# Out:
# Installing Python dependencies... (This may take 3-5 minutes)
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu121, https://download.pytorch.org/whl/cu128
# Ignoring torch: markers 'sys_platform == "win32"' don't match your environment
# Ignoring torchaudio: markers 'sys_platform == "win32"' don't match your environment
# Ignoring torchvision: markers 'sys_platform == "win32"' don't match your environment
# Ignoring triton-windows: markers 'sys_platform == "win32"' don't match your environment
# Ignoring flash-attn: markers 'sys_platform == "win32" and python_version == "3.11" and platform_machine == "AMD64"' don't match your environment
# Ignoring flash-attn: markers 'sys_platform == "linux" and python_version == "3.11"' don't match your environment
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (2.10.0+cu128)
# Requirement already satisfied: torchaudio>=2.9.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (2.10.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (0.25.0+cu128)
# Requirement already satisfied: transformers<4.58.0,>=4.51.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (4.57.6)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (0.36.0)
# Requirement already satisfied: gradio==6.2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (6.2.0)
# Requirement already satisfied: matplotlib>=3.7.5 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 14)) (3.10.0)
# Requirement already satisfied: scipy>=1.10.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 15)) (1.16.3)
# Requirement already satisfied: soundfile>=0.13.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 16)) (0.13.1)
# Requirement already satisfied: loguru>=0.7.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 17)) (0.7.3)
# Requirement already satisfied: einops>=0.8.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 18)) (0.8.2)
# Requirement already satisfied: accelerate>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 19)) (1.12.0)
# Requirement already satisfied: fastapi>=0.110.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 20)) (0.128.2)
# Requirement already satisfied: diskcache in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 21)) (5.6.3)
# Requirement already satisfied: uvicorn>=0.27.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.27.0->-r requirements.txt (line 22)) (0.40.0)
# Requirement already satisfied: numba>=0.63.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 23)) (0.63.1)
# Requirement already satisfied: vector-quantize-pytorch>=1.27.15 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 24)) (1.27.21)
# Requirement already satisfied: peft>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 28)) (0.18.1)
# Requirement already satisfied: lightning>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 29)) (2.6.1)
# Requirement already satisfied: triton>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 33)) (3.6.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 36)) (3.6.0)
# Requirement already satisfied: spaces in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 39)) (0.47.0)
# Requirement already satisfied: huggingface_hub>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 40)) (0.36.2)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio==6.2.0->-r requirements.txt (line 13)) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio==6.2.0->-r requirements.txt (line 13)) (4.12.1)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio==6.2.0->-r requirements.txt (line 13)) (1.2.0)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio==6.2.0->-r requirements.txt (line 13)) (1.0.0)
# Requirement already satisfied: gradio-client==2.0.2 in /usr/local/lib/python3.12/dist-packages (from gradio==6.2.0->-r requirements.txt (line 13)) (2.0.2)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio==6.2.0->-r requirements.txt (line 13)) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio==6.2.0->-r requirements.txt (line 13)) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio==6.2.0->-r requirements.txt (line 13)) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==6.2.0->-r requirements.txt (line 13)) (3.0.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio==6.2.0->-r requirements.txt (line 13)) (2.0.2)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio==6.2.0->-r requirements.txt (line 13)) (3.11.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from gradio==6.2.0->-r requirements.txt (line 13)) (26.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio==6.2.0->-r requirements.txt (line 13)) (2.2.2)
# Requirement already satisfied: pillow<13.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio==6.2.0->-r requirements.txt (line 13)) (11.3.0)
# Requirement already satisfied: pydantic<=3.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==6.2.0->-r requirements.txt (line 13)) (2.12.3)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio==6.2.0->-r requirements.txt (line 13)) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio==6.2.0->-r requirements.txt (line 13)) (0.0.22)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from gradio==6.2.0->-r requirements.txt (line 13)) (6.0.3)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.7 in /usr/local/lib/python3.12/dist-packages (from gradio==6.2.0->-r requirements.txt (line 13)) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==6.2.0->-r requirements.txt (line 13)) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio==6.2.0->-r requirements.txt (line 13)) (0.50.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio==6.2.0->-r requirements.txt (line 13)) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio==6.2.0->-r requirements.txt (line 13)) (0.21.1)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.12/dist-packages (from gradio==6.2.0->-r requirements.txt (line 13)) (4.15.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio-client==2.0.2->gradio==6.2.0->-r requirements.txt (line 13)) (2025.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 6)) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 6)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 6)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 6)) (3.6.1)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 6)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 6)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 6)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 6)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 6)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 6)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 6)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 6)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 6)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 6)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 6)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 6)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 6)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 6)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 6)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 6)) (1.13.1.3)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->-r requirements.txt (line 6)) (1.3.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<4.58.0,>=4.51.0->-r requirements.txt (line 11)) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers<4.58.0,>=4.51.0->-r requirements.txt (line 11)) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<4.58.0,>=4.51.0->-r requirements.txt (line 11)) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<4.58.0,>=4.51.0->-r requirements.txt (line 11)) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers<4.58.0,>=4.51.0->-r requirements.txt (line 11)) (4.67.3)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.12/dist-packages (from diffusers->-r requirements.txt (line 12)) (8.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->-r requirements.txt (line 14)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->-r requirements.txt (line 14)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->-r requirements.txt (line 14)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->-r requirements.txt (line 14)) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->-r requirements.txt (line 14)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->-r requirements.txt (line 14)) (2.9.0.post0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.13.1->-r requirements.txt (line 16)) (2.0.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.12.0->-r requirements.txt (line 19)) (5.9.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.110.0->-r requirements.txt (line 20)) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.110.0->-r requirements.txt (line 20)) (0.0.4)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn>=0.27.0->uvicorn[standard]>=0.27.0->-r requirements.txt (line 22)) (8.3.1)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn>=0.27.0->uvicorn[standard]>=0.27.0->-r requirements.txt (line 22)) (0.16.0)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.63.1->-r requirements.txt (line 23)) (0.46.0)
# Requirement already satisfied: einx>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from vector-quantize-pytorch>=1.27.15->-r requirements.txt (line 24)) (0.3.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0.0->-r requirements.txt (line 29)) (0.15.2)
# Requirement already satisfied: torchmetrics<3.0,>0.7.0 in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0.0->-r requirements.txt (line 29)) (1.8.2)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.12/dist-packages (from lightning>=2.0.0->-r requirements.txt (line 29)) (2.6.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.20.0->-r requirements.txt (line 40)) (1.2.0)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.27.0->-r requirements.txt (line 22)) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.27.0->-r requirements.txt (line 22)) (1.2.1)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.27.0->-r requirements.txt (line 22)) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.27.0->-r requirements.txt (line 22)) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.27.0->-r requirements.txt (line 22)) (15.0.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio==6.2.0->-r requirements.txt (line 13)) (3.11)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.13.1->-r requirements.txt (line 16)) (3.0)
# Requirement already satisfied: frozendict in /usr/local/lib/python3.12/dist-packages (from einx>=0.3.0->vector-quantize-pytorch>=1.27.15->-r requirements.txt (line 24)) (2.4.7)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0.0->-r requirements.txt (line 29)) (3.13.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio==6.2.0->-r requirements.txt (line 13)) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio==6.2.0->-r requirements.txt (line 13)) (1.0.9)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio==6.2.0->-r requirements.txt (line 13)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio==6.2.0->-r requirements.txt (line 13)) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<=3.0,>=2.0->gradio==6.2.0->-r requirements.txt (line 13)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<=3.0,>=2.0->gradio==6.2.0->-r requirements.txt (line 13)) (2.41.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7.5->-r requirements.txt (line 14)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<4.58.0,>=4.51.0->-r requirements.txt (line 11)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<4.58.0,>=4.51.0->-r requirements.txt (line 11)) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio==6.2.0->-r requirements.txt (line 13)) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio==6.2.0->-r requirements.txt (line 13)) (13.9.4)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata->diffusers->-r requirements.txt (line 12)) (3.23.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0.0->-r requirements.txt (line 29)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0.0->-r requirements.txt (line 29)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0.0->-r requirements.txt (line 29)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0.0->-r requirements.txt (line 29)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0.0->-r requirements.txt (line 29)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0.0->-r requirements.txt (line 29)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning>=2.0.0->-r requirements.txt (line 29)) (1.22.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio==6.2.0->-r requirements.txt (line 13)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio==6.2.0->-r requirements.txt (line 13)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio==6.2.0->-r requirements.txt (line 13)) (0.1.2)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.
# ✅ Dependencies installed.

# %%
# @title 3. Download Models & Launch Interface
# This cell first downloads the heavy model files (safetensors) and then starts the app.
import os

if os.getcwd() != "/content/Ace-Step-v1.5":
    os.chdir("/content/Ace-Step-v1.5")

# --- LITE MODE CONFIG ---
os.environ["SERVICE_MODE_DIT_MODEL_2"] = "" # Disable 2nd model download/load
os.environ["SERVICE_MODE_BACKEND"] = "vllm"

# 1. CREATE DOWNLOAD SCRIPT
# Note: Double backslashes (\\n) are used to prevent Python from breaking strings across lines in the file
download_code = """
import os
import sys
import torch

print("Initializing download sequence...")
current_dir = os.getcwd()
sys.path.insert(0, os.path.join(current_dir, "acestep", "third_parts", "nano-vllm"))

from acestep.handler import AceStepHandler

# Initialize handler to trigger download logic
# We force CPU offload to avoid filling GPU RAM just for downloading
handler = AceStepHandler(persistent_storage_path=os.path.join(current_dir, "data"))

print("Downloading ACE-Step v1.5 Unified Repo (This includes DiT and LLM)...")
print("This may take a while (approx 10GB)...")

config_path = "acestep-v15-turbo"

# Use internal method if available to force download, otherwise init
try:
    if hasattr(handler, '_ensure_model_downloaded'):
        handler._ensure_model_downloaded(current_dir, config_path)
        print("\\n✅ Download complete.")
    else:
        print("Standard initialization...")
        handler.initialize_service(current_dir, config_path, device='cpu', offload_to_cpu=True)
except Exception as e:
    print(f"\\nDownload process finished (check for errors above if any): {e}")
"""

with open("download_models.py", "w") as f:
    f.write(download_code)

# 2. RUN DOWNLOAD
print("⏳ Starting Model Download... (This prevents timeouts)")
# !python download_models.py

# 3. LAUNCH APP
print("="*60)
print("🚀 Models ready. Launching ACE-Step Interface...")
print("🔗 Click the public link ending in 'gradio.live' below once it appears.")
print("="*60)

# !python app.py
# Out:
# ⏳ Starting Model Download... (This prevents timeouts)
# Initializing download sequence...
# 2026-02-14 02:57:20.374726: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771037840.586554   16775 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771037840.642501   16775 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771037841.061054   16775 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771037841.061105   16775 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771037841.061111   16775 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771037841.061115   16775 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-14 02:57:21.109212: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Downloading ACE-Step v1.5 Unified Repo (This includes DiT and LLM)...
# This may take a while (approx 10GB)...
# 2026-02-14 02:57:29.152 | INFO     | acestep.handler:_ensure_model_downloaded:168 - Model /content/Ace-Step-v1.5 already exists at /content/Ace-Step-v1.5
#
# ✅ Download complete.
# ============================================================
# 🚀 Models ready. Launching ACE-Step Interface...
# 🔗 Click the public link ending in 'gradio.live' below once it appears.
# ============================================================
# 2026-02-14 02:57:41.322913: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771037861.343345   16922 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771037861.350224   16922 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771037861.368110   16922 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771037861.368136   16922 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771037861.368140   16922 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771037861.368149   16922 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-14 02:57:41.372699: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Using local storage (non-persistent): /content/Ace-Step-v1.5/data
# Note: To enable persistent storage, configure it in HuggingFace Space settings
# Detected GPU memory: 14.56 GB (< 16GB)
# Auto-enabling CPU offload to reduce GPU memory usage
# Creating handlers...
# Service mode configuration:
#   DiT model 1: acestep-v15-turbo
#   LM model: acestep-5Hz-lm-1.7B
#   Backend: vllm
#   Offload to CPU: True
#   DEBUG_UI: False
#   Flash Attention: False
# Initializing DiT model 1: acestep-v15-turbo...
# 2026-02-14 02:57:51.778 | INFO     | acestep.handler:initialize_service:436 - [initialize_service] Attempting to load model with attention implementation: sdpa
# 2026-02-14 02:57:53.188 | INFO     | acestep.handler:initialize_service:464 - [initialize_service] Keeping main model on cuda (persistent)
# DiT model 1 initialized successfully
# Initializing 5Hz LM: acestep-5Hz-lm-1.7B...
# 2026-02-14 02:58:19.829 | INFO     | acestep.llm_inference:initialize:330 - loading 5Hz LM tokenizer... it may take 80~90s
# 2026-02-14 02:58:48.044 | INFO     | acestep.llm_inference:initialize:334 - 5Hz LM tokenizer loaded successfully in 28.22 seconds
# 2026-02-14 02:58:48.044 | INFO     | acestep.llm_inference:initialize:338 - Initializing constrained decoding processor...
# 2026-02-14 02:58:49.406 | WARNING  | acestep.constrained_logits_processor:_precompute_audio_code_tokens:545 - Found 1535 audio code tokens with values outside valid range [0, 63999]
# 2026-02-14 02:58:53.729 | INFO     | acestep.llm_inference:initialize:345 - Constrained processor initialized in 5.68 seconds
# 2026-02-14 02:58:55.006 | ERROR    | acestep.llm_inference:_initialize_5hz_lm_vllm:383 - nano-vllm is not installed. Please install it using 'cd acestep/third_parts/nano-vllm && pip install .
# 2026-02-14 02:58:55.006 | INFO     | acestep.llm_inference:initialize:351 - 5Hz LM status message: ❌ nano-vllm is not installed. Please install it using 'cd acestep/third_parts/nano-vllm && pip install .
# 2026-02-14 02:58:55.006 | WARNING  | acestep.llm_inference:initialize:356 - vllm initialization failed, falling back to PyTorch backend
# 2026-02-14 02:59:12.885 | INFO     | acestep.llm_inference:_load_pytorch_model:205 - 5Hz LM initialized successfully using PyTorch backend on cuda
# 5Hz LM initialized successfully
# Service initialization completed!
# Creating Gradio interface...
# Enabling queue for multi-user support...
# Launching server on 0.0.0.0:7860...
# * Running on local URL:  http://0.0.0.0:7860
# * Running on public URL: https://df57fa1d35febcd5da.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# 2026-02-14 03:00:13.413 | INFO     | acestep.inference:generate_music:377 - [generate_music] LLM usage decision: thinking=True, use_cot_caption=True, use_cot_language=True, use_cot_metas=True, need_lm_for_cot=True, llm_initialized=True, use_lm=True
# 2026-02-14 03:00:13.413 | INFO     | acestep.inference:generate_music:435 - LM chunk 1/1 (infer_type=llm_dit) (size: 2, seeds: [1627113097, 4121875713])
# 2026-02-14 03:00:13.413 | INFO     | acestep.llm_inference:generate_with_stop_condition:919 - Batch Phase 1: Generating CoT metadata (once for all items)...
# 2026-02-14 03:00:13.452 | INFO     | acestep.llm_inference:generate_with_stop_condition:927 - generate_with_stop_condition: formatted_prompt=<|im_start|>system
# # Instruction
# Generate audio semantic tokens based on the given conditions:
#
# <|im_end|>
# <|im_start|>user
# # Caption
# Montagem Coral, Brazilian Funk, Funk Mandelão, Heavy Sub-Bass, Rhythmic Stutter, Repetitive Vocals, 130 BPM, Dark Vibes, Aggressive Phonk, Viral TikTok Style.
#
# # Lyric
# [style: Montagem, Repetitive Flow]
#
# [intro]
# (Tiếng đồng hồ tích tắc... nhanh dần)
# Time... Time... Time...
# Pressure!
#
# [chorus]
# Time is ticking, time is ticking, pressure on my mind
# Life is crazy, dangerous, leaving all behind
# Keep on running, keep on running, never press rewind
# In the hustle, in the hustle, seek and you shall find
#
# [loop 1]
# Time is ticking, time is ticking, pressure on my mind
# Life is crazy, dangerous, leaving all behind
# Time is ticking, time is ticking, pressure on my mind
# Life is crazy, dangerous, leaving all behind
#
# [loop 2]
# Time is ticking, time is ticking, pressure on my mind
# Life is crazy, dangerous, leaving all behind
# Keep on running, keep on running, never press rewind
# In the hustle, in the hustle, seek and you shall find
#
# [drop]
# (Bass dồn dập - Stutter vocal)
# Ti-Ti-Time is ticking! (Tick!)
# Pre-Pre-Pressure! (Tock!)
# Ti-Ti-Time is ticking! (Tick!)
# Pre-Pre-Pressure! (Tock!)
#
# [outro]
# Leaving all behind.
# Leaving all behind.
# Time's up.
# <|im_end|>
# <|im_start|>assistant
#
# 2026-02-14 03:00:13.492 | INFO     | acestep.llm_inference:_load_model_context:2327 - Loading LLM to cuda
# 2026-02-14 03:00:14.793 | INFO     | acestep.llm_inference:_load_model_context:2332 - Loaded LLM to cuda in 1.3008s
# 2026-02-14 03:00:40.201 | INFO     | acestep.llm_inference:_load_model_context:2338 - Offloading LLM to CPU
# 2026-02-14 03:00:42.979 | INFO     | acestep.llm_inference:_load_model_context:2344 - Offloaded LLM to CPU in 2.7781s
# 2026-02-14 03:00:42.980 | DEBUG    | acestep.llm_inference:parse_lm_output:2207 - Debug output text: <think>
# bpm: 130
# caption: 'An aggressive hard dance track slammed truestyle with Korean hip-hop influences.
#   The song is driven by heavily distorted kicks and sharp synth stabs that lock into
#   an intense groove. A dual-vocal approach alternates between assertive male rap verses
#   delivered in both English and Korean, processed with distortion to blend into the
#   chaotic mix. Female vocals provide catchy hooks and ad-libs over pitched-up vocal
#   chop melodies. The arrangement features classic EDM dynamics: tense build-ups using
#   snare rolls and risers leading into powerful drops where chopped vocal samples become
#   rhythmic hooks. A brief breakdown offers a momentary change in texture before launching
#   back into high-energy sections filled with stuttering edits and a driving four-on-the-floor
# :duration: 90
# keyscale: C major
# language: vi
# timesignature: 4
# <|im_end|>
# 2026-02-14 03:00:42.981 | INFO     | acestep.llm_inference:generate_with_stop_condition:967 - Batch Phase 1 completed in 29.57s. Generated metadata: ['bpm', 'caption', 'keyscale', 'language', 'timesignature']
# 2026-02-14 03:00:42.981 | INFO     | acestep.llm_inference:generate_with_stop_condition:1010 - Batch Phase 2: Generating audio codes for 2 items...
# 2026-02-14 03:00:42.985 | INFO     | acestep.llm_inference:generate_with_stop_condition:1020 - generate_with_stop_condition: formatted_prompt_with_cot=<|im_start|>system
# # Instruction
# Generate audio semantic tokens based on the given conditions:
#
# <|im_end|>
# <|im_start|>user
# # Caption
# Montagem Coral, Brazilian Funk, Funk Mandelão, Heavy Sub-Bass, Rhythmic Stutter, Repetitive Vocals, 130 BPM, Dark Vibes, Aggressive Phonk, Viral TikTok Style.
#
# # Lyric
# [style: Montagem, Repetitive Flow]
#
# [intro]
# (Tiếng đồng hồ tích tắc... nhanh dần)
# Time... Time... Time...
# Pressure!
#
# [chorus]
# Time is ticking, time is ticking, pressure on my mind
# Life is crazy, dangerous, leaving all behind
# Keep on running, keep on running, never press rewind
# In the hustle, in the hustle, seek and you shall find
#
# [loop 1]
# Time is ticking, time is ticking, pressure on my mind
# Life is crazy, dangerous, leaving all behind
# Time is ticking, time is ticking, pressure on my mind
# Life is crazy, dangerous, leaving all behind
#
# [loop 2]
# Time is ticking, time is ticking, pressure on my mind
# Life is crazy, dangerous, leaving all behind
# Keep on running, keep on running, never press rewind
# In the hustle, in the hustle, seek and you shall find
#
# [drop]
# (Bass dồn dập - Stutter vocal)
# Ti-Ti-Time is ticking! (Tick!)
# Pre-Pre-Pressure! (Tock!)
# Ti-Ti-Time is ticking! (Tick!)
# Pre-Pre-Pressure! (Tock!)
#
# [outro]
# Leaving all behind.
# Leaving all behind.
# Time's up.
# <|im_end|>
# <|im_start|>assistant
# <think>
# bpm: 130
# caption: '''An aggressive hard dance track slammed truestyle with Korean hip-hop influences.
#   The song is driven by heavily distorted kicks and sharp synth stabs that lock into
#   an intense groove. A dual-vocal approach alternates between assertive male rap verses
#   delivered in both English and Korean, processed with distortion to blend into the
#   chaotic mix. Female vocals provide catchy hooks and ad-libs over pitched-up vocal
#   chop melodies. The arrangement features classic EDM dynamics: tense build-ups using
#   snare rolls and risers leading into powerful drops where chopped vocal samples become
#   rhythmic hooks. A brief breakdown offers a momentary change in texture before launching
#   back into high-energy sections filled with stuttering edits and a driving four-on-the-floor'
# keyscale: C major
# language: vi
# timesignature: 4
# </think>
#
# <|im_end|>
#
# 2026-02-14 03:00:43.013 | INFO     | acestep.llm_inference:_load_model_context:2327 - Loading LLM to cuda
# 2026-02-14 03:00:43.995 | INFO     | acestep.llm_inference:_load_model_context:2332 - Loaded LLM to cuda in 0.9822s
# 2026-02-14 03:01:45.275 | INFO     | acestep.llm_inference:_load_model_context:2338 - Offloading LLM to CPU
# 2026-02-14 03:01:46.768 | INFO     | acestep.llm_inference:_load_model_context:2344 - Offloaded LLM to CPU in 1.4929s
# 2026-02-14 03:01:46.772 | INFO     | acestep.llm_inference:_load_model_context:2327 - Loading LLM to cuda
# 2026-02-14 03:01:47.748 | INFO     | acestep.llm_inference:_load_model_context:2332 - Loaded LLM to cuda in 0.9754s
# 2026-02-14 03:02:50.783 | INFO     | acestep.llm_inference:_load_model_context:2338 - Offloading LLM to CPU
# 2026-02-14 03:02:52.439 | INFO     | acestep.llm_inference:_load_model_context:2344 - Offloaded LLM to CPU in 1.6559s
# 2026-02-14 03:02:52.440 | DEBUG    | acestep.llm_inference:parse_lm_output:2207 - Debug output text: <|audio_code_26071|><|audio_code_11167|><|audio_code_8615|><|audio_code_33750|><|audio_code_36831|><|audio_code_36767|><|audio_code_35790|><|audio_code_35799|><|audio_code_50615|><|audio_code_35323|><|audio_code_22981|><|audio_code_25589|><|audio_code_54213|><|audio_code_11171|><|audio_code_11247|><|audio_code_54268|><|audio_code_8671|><|audio_code_57292|><|audio_code_8085|><|audio_code_38799|><|audio_code_36819|><|audio_code_56319|><|audio_code_955|><|audio_code_14727|><|audio_code_4094|><|audio_code_501|><|audio_code_54271|><|audio_code_13300|><|audio_code_455|><|audio_code_10742|><|audio_code_29183|><|audio_code_27631|><|audio_code_51711|><|audio_code_48639|><|audio_code_28630|><|audio_code_49125|><|audio_code_44030|><|audio_code_31743|><|audio_code_26047|><|audio_code_41863|><|audio_code_13199|><|audio_code_26511|><|audio_code_25999|><|audio_code_26583|><|audio_code_23533|><|audio_code_29062|><|audio_code_39395|><|audio_code_11650|><|audio_code_12747|><|audio_code_30687|><|audio_code_24029|><|audio_code_10303|><|audio_code_62479|><|audio_code_26113|><|audio_code_26568|><|audio_code_15136|><|audio_code_24919|><|audio_code_2671|><|audio_code_60743|><|audio_code_14999|><|audio_code_10631|><|audio_code_53535|><|audio_code_1159|><|audio_code_31784|><|audio_code_51591|><|audio_code_1010|><|audio_code_49554|><|audio_code_40434|><|audio_code_54215|><|audio_code_12693|><|audio_code_20316|><|audio_code_26611|><|audio_code_450|><|audio_code_15344|><|audio_code_53170|><|audio_code_56567|><|audio_code_23523|><|audio_code_33127|><|audio_code_40925|><|audio_code_24543|><|audio_code_14983|><|audio_code_30473|><|audio_code_35821|><|audio_code_14787|><|audio_code_36837|><|audio_code_50609|><|audio_code_28612|><|audio_code_12740|><|audio_code_13299|><|audio_code_26118|><|audio_code_32705|><|audio_code_2440|><|audio_code_11675|><|audio_code_30695|><|audio_code_39844|><|audio_code_28154|><|audio_code_50063|><|audio_code_53235|><|audio_code_58783|><|audio_code_51974|><|audio_code_25728|><|audio_code_47614|><|audio_code_3522|><|audio_code_50515|><|audio_code_53739|><|audio_code_59358|><|audio_code_23506|><|audio_code_18279|><|audio_code_40917|><|audio_code_13763|><|audio_code_15296|><|audio_code_43507|><|audio_code_28343|><|audio_code_14837|><|audio_code_25447|><|audio_code_14801|><|audio_code_13807|><|audio_code_25783|><|audio_code_17608|><|audio_code_33230|><|audio_code_10742|><|audio_code_24028|><|audio_code_12172|><|audio_code_28111|><|audio_code_36305|><|audio_code_13815|><|audio_code_26245|><|audio_code_27621|><|audio_code_38338|><|audio_code_41959|><|audio_code_22991|><|audio_code_964|><|audio_code_23447|><|audio_code_26518|><|audio_code_38327|><|audio_code_34711|><|audio_code_51167|><|audio_code_27599|><|audio_code_62926|><|audio_code_28145|><|audio_code_21956|><|audio_code_30660|><|audio_code_25083|><|audio_code_14732|><|audio_code_19404|><|audio_code_25045|><|audio_code_454|><|audio_code_10706|><|audio_code_2558|><|audio_code_27851|><|audio_code_17228|><|audio_code_13092|><|audio_code_1372|><|audio_code_27911|><|audio_code_38791|><|audio_code_13308|><|audio_code_21444|><|audio_code_40372|><|audio_code_36301|><|audio_code_5006|><|audio_code_23020|><|audio_code_36299|><|audio_code_2947|><|audio_code_12162|><|audio_code_52955|><|audio_code_25580|><|audio_code_61907|><|audio_code_47597|><|audio_code_28124|><|audio_code_387|><|audio_code_12627|><|audio_code_5293|><|audio_code_14276|><|audio_code_14837|><|audio_code_37359|><|audio_code_11732|><|audio_code_3020|><|audio_code_36307|><|audio_code_2229|><|audio_code_15233|><|audio_code_32194|><|audio_code_13197|><|audio_code_1429|><|audio_code_23022|><|audio_code_49106|><|audio_code_25907|><|audio_code_38369|><|audio_code_28140|><|audio_code_2500|><|audio_code_15252|><|audio_code_25405|><|audio_code_31684|><|audio_code_386|><|audio_code_21124|><|audio_code_35838|><|audio_code_53547|><|audio_code_ ...
# 2026-02-14 03:02:52.441 | DEBUG    | acestep.llm_inference:parse_lm_output:2207 - Debug output text: <|audio_code_26071|><|audio_code_48983|><|audio_code_34791|><|audio_code_35735|><|audio_code_9724|><|audio_code_36647|><|audio_code_33237|><|audio_code_25700|><|audio_code_51413|><|audio_code_61906|><|audio_code_53242|><|audio_code_2427|><|audio_code_29170|><|audio_code_63921|><|audio_code_24449|><|audio_code_51009|><|audio_code_27396|><|audio_code_40860|><|audio_code_30656|><|audio_code_25058|><|audio_code_13643|><|audio_code_38345|><|audio_code_40706|><|audio_code_35083|><|audio_code_24403|><|audio_code_4501|><|audio_code_58868|><|audio_code_61890|><|audio_code_36408|><|audio_code_33725|><|audio_code_38704|><|audio_code_29265|><|audio_code_14100|><|audio_code_53252|><|audio_code_53710|><|audio_code_18891|><|audio_code_33918|><|audio_code_25628|><|audio_code_41574|><|audio_code_58591|><|audio_code_52751|><|audio_code_20191|><|audio_code_51055|><|audio_code_61907|><|audio_code_29054|><|audio_code_26055|><|audio_code_40770|><|audio_code_25554|><|audio_code_39730|><|audio_code_12226|><|audio_code_25473|><|audio_code_38281|><|audio_code_40642|><|audio_code_32522|><|audio_code_11547|><|audio_code_53653|><|audio_code_37841|><|audio_code_56011|><|audio_code_25536|><|audio_code_37184|><|audio_code_40705|><|audio_code_40203|><|audio_code_28059|><|audio_code_15297|><|audio_code_63979|><|audio_code_27779|><|audio_code_43478|><|audio_code_27408|><|audio_code_50836|><|audio_code_25301|><|audio_code_25366|><|audio_code_13839|><|audio_code_33094|><|audio_code_12231|><|audio_code_40455|><|audio_code_2071|><|audio_code_14383|><|audio_code_51871|><|audio_code_14447|><|audio_code_27959|><|audio_code_13764|><|audio_code_42047|><|audio_code_15407|><|audio_code_27579|><|audio_code_15315|><|audio_code_56246|><|audio_code_2550|><|audio_code_20409|><|audio_code_24513|><|audio_code_37753|><|audio_code_37755|><|audio_code_27403|><|audio_code_56212|><|audio_code_37824|><|audio_code_8066|><|audio_code_12738|><|audio_code_50554|><|audio_code_1729|><|audio_code_45322|><|audio_code_24469|><|audio_code_56284|><|audio_code_12740|><|audio_code_62426|><|audio_code_30112|><|audio_code_136|><|audio_code_44160|><|audio_code_27980|><|audio_code_15069|><|audio_code_51845|><|audio_code_26631|><|audio_code_2095|><|audio_code_26639|><|audio_code_53509|><|audio_code_31630|><|audio_code_1814|><|audio_code_52807|><|audio_code_56135|><|audio_code_4483|><|audio_code_38150|><|audio_code_33068|><|audio_code_41143|><|audio_code_37829|><|audio_code_19822|><|audio_code_38398|><|audio_code_11771|><|audio_code_50991|><|audio_code_37819|><|audio_code_45703|><|audio_code_27019|><|audio_code_24806|><|audio_code_50630|><|audio_code_12669|><|audio_code_24959|><|audio_code_37817|><|audio_code_29375|><|audio_code_47434|><|audio_code_27791|><|audio_code_50630|><|audio_code_48620|><|audio_code_6000|><|audio_code_5354|><|audio_code_11255|><|audio_code_53252|><|audio_code_49879|><|audio_code_2151|><|audio_code_40631|><|audio_code_25047|><|audio_code_11735|><|audio_code_8172|><|audio_code_63679|><|audio_code_18407|><|audio_code_29295|><|audio_code_53407|><|audio_code_27975|><|audio_code_974|><|audio_code_35983|><|audio_code_17349|><|audio_code_23287|><|audio_code_22511|><|audio_code_35039|><|audio_code_25543|><|audio_code_23455|><|audio_code_49415|><|audio_code_38399|><|audio_code_38599|><|audio_code_25071|><|audio_code_63631|><|audio_code_63823|><|audio_code_14695|><|audio_code_24455|><|audio_code_23527|><|audio_code_11583|><|audio_code_25799|><|audio_code_21167|><|audio_code_21791|><|audio_code_7447|><|audio_code_18679|><|audio_code_49295|><|audio_code_27727|><|audio_code_2183|><|audio_code_1079|><|audio_code_26191|><|audio_code_53383|><|audio_code_4223|><|audio_code_16407|><|audio_code_26191|><|audio_code_47687|><|audio_code_27839|><|audio_code_5638|><|audio_code_27743|><|audio_code_35511|><|audio_code_26639|><|audio_code_15959|><|audio_code_52839|><|audio_code_27684|><|audio_code_13756|><| ...
# 2026-02-14 03:02:52.453 | INFO     | acestep.llm_inference:generate_with_stop_condition:1094 - Batch Phase 2 completed in 129.47s. Generated codes: [450, 450]
# 2026-02-14 03:02:52.454 | INFO     | acestep.handler:generate_music:2748 - [generate_music] Starting generation...
# 2026-02-14 03:02:52.454 | INFO     | acestep.handler:generate_music:2751 - [generate_music] Preparing inputs...
# 2026-02-14 03:02:52.454 | INFO     | acestep.handler:generate_music:2775 - [generate_music] Processing reference audio...
# 2026-02-14 03:02:53.170 | DEBUG    | acestep.handler:_load_audio_file:1139 - [_load_audio_file] ffmpeg backend failed: Could not load libtorchcodec. Likely causes:
#           1. FFmpeg is not properly installed in your environment. We support
#              versions 4, 5, 6 and 7.
#           2. The PyTorch version (2.10.0+cu128) is not compatible with
#              this version of TorchCodec. Refer to the version compatibility
#              table:
#              https://github.com/pytorch/torchcodec?tab=readme-ov-file#installing-torchcodec.
#           3. Another runtime dependency; see exceptions below.
#         The following exceptions were raised as we tried to load libtorchcodec:
#
# [start of libtorchcodec loading traceback]
# FFmpeg version 8: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchcodec/libtorchcodec_core8.so
# FFmpeg version 7: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchcodec/libtorchcodec_core7.so
# FFmpeg version 6: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchcodec/libtorchcodec_core6.so
# FFmpeg version 5: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchcodec/libtorchcodec_core5.so
# FFmpeg version 4: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchcodec/libtorchcodec_core4.so
# [end of libtorchcodec loading traceback]., trying soundfile fallback
# 2026-02-14 03:02:53.333 | DEBUG    | acestep.handler:process_reference_audio:1417 - [process_reference_audio] Reference audio shape: torch.Size([2, 3934208])
# 2026-02-14 03:02:53.333 | DEBUG    | acestep.handler:process_reference_audio:1418 - [process_reference_audio] Reference audio sample rate: 44100
# 2026-02-14 03:02:53.333 | DEBUG    | acestep.handler:process_reference_audio:1419 - [process_reference_audio] Reference audio duration: 81.96266666666666 seconds
# 2026-02-14 03:02:53.869 | INFO     | acestep.handler:_load_model_context:719 - [_load_model_context] Loading vae to cuda
# 2026-02-14 03:02:54.085 | INFO     | acestep.handler:_load_model_context:732 - [_load_model_context] Loaded vae to cuda in 0.2161s
# 2026-02-14 03:02:54.085 | INFO     | acestep.handler:_prepare_batch:1825 - [generate_music] Decoding audio codes for item 0...
# 2026-02-14 03:02:54.443 | INFO     | acestep.handler:_prepare_batch:1825 - [generate_music] Decoding audio codes for item 1...
# 2026-02-14 03:02:54.678 | INFO     | acestep.handler:_load_model_context:738 - [_load_model_context] Offloading vae to CPU
# 2026-02-14 03:02:55.122 | INFO     | acestep.handler:_load_model_context:749 - [_load_model_context] Offloaded vae to CPU in 0.4431s
# 2026-02-14 03:02:55.172 | INFO     | acestep.handler:_prepare_batch:1997 - [generate_music] Decoding audio codes for LM hints for item 0...
# 2026-02-14 03:02:55.182 | INFO     | acestep.handler:_prepare_batch:1997 - [generate_music] Decoding audio codes for LM hints for item 1...
# 2026-02-14 03:02:55.635 | INFO     | acestep.handler:_load_model_context:719 - [_load_model_context] Loading vae to cuda
# 2026-02-14 03:02:55.807 | INFO     | acestep.handler:_load_model_context:732 - [_load_model_context] Loaded vae to cuda in 0.1714s
# 2026-02-14 03:03:01.448 | INFO     | acestep.handler:_load_model_context:738 - [_load_model_context] Offloading vae to CPU
# 2026-02-14 03:03:01.709 | INFO     | acestep.handler:_load_model_context:749 - [_load_model_context] Offloaded vae to CPU in 0.2605s
# 2026-02-14 03:03:01.709 | INFO     | acestep.handler:preprocess_batch:2254 - [preprocess_batch] Inferring prompt embeddings...
# 2026-02-14 03:03:01.709 | INFO     | acestep.handler:_load_model_context:719 - [_load_model_context] Loading text_encoder to cuda
# `loss_type=None` was set in the config but it is unrecognized. Using the default loss: `ForCausalLMLoss`.
# 2026-02-14 03:03:02.526 | INFO     | acestep.handler:_load_model_context:732 - [_load_model_context] Loaded text_encoder to cuda in 0.8169s
# 2026-02-14 03:03:02.641 | INFO     | acestep.handler:preprocess_batch:2257 - [preprocess_batch] Inferring lyric embeddings...
# 2026-02-14 03:03:02.641 | INFO     | acestep.handler:_load_model_context:738 - [_load_model_context] Offloading text_encoder to CPU
# 2026-02-14 03:03:03.902 | INFO     | acestep.handler:_load_model_context:749 - [_load_model_context] Offloaded text_encoder to CPU in 1.2600s
# 2026-02-14 03:03:03.902 | INFO     | acestep.handler:service_generate:2490 - [service_generate] Generating audio...
# Using precomputed LM hints
# Using precomputed LM hints
# 2026-02-14 03:03:35.401 | INFO     | acestep.handler:generate_music:2859 - [generate_music] Model generation completed. Decoding latents...
# 2026-02-14 03:03:36.710 | DEBUG    | acestep.handler:generate_music:2863 - [generate_music] pred_latents: torch.Size([2, 2250, 64]), dtype=torch.bfloat16 pred_latents.min()=tensor(-7.1250, device='cuda:0', dtype=torch.bfloat16), pred_latents.max()=tensor(4.6250, device='cuda:0', dtype=torch.bfloat16), pred_latents.mean()=tensor(-0.0593, device='cuda:0', dtype=torch.bfloat16) pred_latents.std()=tensor(1.0078, device='cuda:0', dtype=torch.bfloat16)
# 2026-02-14 03:03:36.710 | DEBUG    | acestep.handler:generate_music:2864 - [generate_music] time_costs: {'encoder_time_cost': 0.5391385555267334, 'diffusion_time_cost': 30.35983681678772, 'diffusion_per_step_time_cost': 3.794979602098465, 'total_time_cost': 30.898975372314453, 'offload_time_cost': 3.168001413345337}
# 2026-02-14 03:03:36.711 | INFO     | acestep.handler:generate_music:2867 - [generate_music] Decoding latents with VAE...
# 2026-02-14 03:03:36.711 | INFO     | acestep.handler:_load_model_context:719 - [_load_model_context] Loading vae to cuda
# 2026-02-14 03:03:36.893 | INFO     | acestep.handler:_load_model_context:732 - [_load_model_context] Loaded vae to cuda in 0.1818s
# 2026-02-14 03:03:36.894 | INFO     | acestep.handler:generate_music:2879 - [generate_music] Using tiled VAE decode to reduce VRAM usage...
# Decoding audio chunks: 100% 6/6 [00:21<00:00,  3.53s/steps]
# 2026-02-14 03:03:58.091 | INFO     | acestep.handler:_load_model_context:738 - [_load_model_context] Offloading vae to CPU
# 2026-02-14 03:03:59.816 | INFO     | acestep.handler:_load_model_context:749 - [_load_model_context] Offloaded vae to CPU in 1.7252s
# 2026-02-14 03:03:59.817 | INFO     | acestep.handler:generate_music:2893 - [generate_music] VAE decode completed. Preparing audio tensors...
# 2026-02-14 03:03:59.865 | INFO     | acestep.handler:generate_music:2908 - [generate_music] Done! Generated 2 audio tensors.
# 2026-02-14 03:04:00.453 | DEBUG    | acestep.audio_utils:save_audio:130 - [AudioSaver] Fallback soundfile Saved audio to /tmp/tmp9edd_8nxacestep_gradio_results/29f933e0-9bf0-0610-672d-28c2f3c8d809.flac (flac, 48000Hz)
# 2026-02-14 03:04:01.241 | DEBUG    | acestep.audio_utils:save_audio:130 - [AudioSaver] Fallback soundfile Saved audio to /tmp/tmp8ai4x1nsacestep_gradio_results/422bd3da-e642-1b26-4a7b-fc875346167c.flac (flac, 48000Hz)
# 2026-02-14 03:15:34.015 | INFO     | acestep.inference:generate_music:377 - [generate_music] LLM usage decision: thinking=True, use_cot_caption=True, use_cot_language=True, use_cot_metas=True, need_lm_for_cot=True, llm_initialized=True, use_lm=True
# 2026-02-14 03:15:34.015 | INFO     | acestep.inference:generate_music:435 - LM chunk 1/1 (infer_type=llm_dit) (size: 2, seeds: [4294967295, 1234567890])
# 2026-02-14 03:15:34.015 | INFO     | acestep.llm_inference:generate_with_stop_condition:919 - Batch Phase 1: Generating CoT metadata (once for all items)...
# 2026-02-14 03:15:34.020 | INFO     | acestep.llm_inference:generate_with_stop_condition:927 - generate_with_stop_condition: formatted_prompt=<|im_start|>system
# # Instruction
# Generate audio semantic tokens based on the given conditions:
#
# <|im_end|>
# <|im_start|>user
# # Caption
# Brazilian Funk, Montagem, Funk Mandelão, Sub-Bass, 130 BPM, Male Vocals, Aggressive, Rhythmic Repetition.
#
# # Lyric
# [style: Montagem, Repetitive Flow]
#
# [intro]
# (Tiếng đồng hồ tích tắc... nhanh dần)
# Time... Time... Time...
# Pressure!
#
# [chorus]
# Time is ticking, time is ticking, pressure on my mind
# Life is crazy, dangerous, leaving all behind
# Keep on running, keep on running, never press rewind
# In the hustle, in the hustle, seek and you shall find
#
# [loop 1]
# Time is ticking, time is ticking, pressure on my mind
# Life is crazy, dangerous, leaving all behind
# Time is ticking, time is ticking, pressure on my mind
# Life is crazy, dangerous, leaving all behind
#
# [loop 2]
# Time is ticking, time is ticking, pressure on my mind
# Life is crazy, dangerous, leaving all behind
# Keep on running, keep on running, never press rewind
# In the hustle, in the hustle, seek and you shall find
#
# [drop]
# (Bass dồn dập - Stutter vocal)
# Ti-Ti-Time is ticking! (Tick!)
# Pre-Pre-Pressure! (Tock!)
# Ti-Ti-Time is ticking! (Tick!)
# Pre-Pre-Pressure! (Tock!)
#
# [outro]
# Leaving all behind.
# Leaving all behind.
# Time's up.
# <|im_end|>
# <|im_start|>assistant
#
# 2026-02-14 03:15:34.023 | INFO     | acestep.llm_inference:_load_model_context:2327 - Loading LLM to cuda
# 2026-02-14 03:15:35.457 | INFO     | acestep.llm_inference:_load_model_context:2332 - Loaded LLM to cuda in 1.4334s
# 2026-02-14 03:15:53.840 | INFO     | acestep.llm_inference:_load_model_context:2338 - Offloading LLM to CPU
