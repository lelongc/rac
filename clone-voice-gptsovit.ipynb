# %% [markdown]
# <a href="https://colab.research.google.com/github/lelongc/rac/blob/main/clone-voice-gptsovit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GPT-SoVITS WebUI

# %% [markdown]
# ## Env Setup (Run Once Only)
# ## 环境配置, 只需运行一次

# %% [markdown]
# ### 1.

# %%
# %%writefile /content/setup.sh
# set -e
#
# cd /content
#
# git clone https://github.com/RVC-Boss/GPT-SoVITS.git
#
# cd GPT-SoVITS
#
# if conda env list | awk '{print $1}' | grep -Fxq "GPTSoVITS"; then
#     :
# else
#     conda create -n GPTSoVITS python=3.10 -y
# fi
#
# source activate GPTSoVITS
#
# pip install ipykernel
#
# bash install.sh --device CU126 --source HF --download-uvr5
# Out:
# Writing /content/setup.sh

# %% [markdown]
# ### 2.

# %%
# %pip install -q condacolab
import condacolab
condacolab.install_from_url("https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh")
# !cd /content && bash setup.sh
# Out:
# ⏬ Downloading https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:01:52
# 🔁 Restarting kernel...
# Cloning into 'GPT-SoVITS'...
# remote: Enumerating objects: 5832, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 5832 (delta 15), reused 4 (delta 4), pack-reused 5803 (from 3)
# Receiving objects: 100% (5832/5832), 14.07 MiB | 14.43 MiB/s, done.
# Resolving deltas: 100% (3342/3342), done.
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/GPTSoVITS
#
#   added / updated specs:
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.12.2  |       h06a4308_0         125 KB
#     expat-2.7.4                |       h7354ed3_0          25 KB
#     ld_impl_linux-64-2.44      |       h153f514_2         672 KB
#     libexpat-2.7.4             |       h7354ed3_0         122 KB
#     libgcc-15.2.0              |       h69a1729_7         806 KB
#     libgcc-ng-15.2.0           |       h166f726_7          28 KB
#     libgomp-15.2.0             |       h4751f2c_7         436 KB
#     libnsl-2.0.0               |       h5eee18b_0          31 KB
#     libstdcxx-15.2.0           |       h39759b7_7         3.7 MB
#     libstdcxx-ng-15.2.0        |       hc03a8fd_7          28 KB
#     libxcb-1.17.0              |       h9b100fa_0         430 KB
#     libzlib-1.3.1              |       hb25bd0a_0          59 KB
#     ncurses-6.5                |       h7934f7d_0         1.1 MB
#     openssl-3.5.5              |       h1b28b03_0         5.5 MB
#     packaging-25.0             |  py310h06a4308_1         164 KB
#     pip-26.0.1                 |     pyhc872135_0         1.1 MB
#     pthread-stubs-0.3          |       h0ce48e5_1           5 KB
#     python-3.10.19             |       h6fa692b_0        24.5 MB
#     readline-8.3               |       hc2a1206_0         471 KB
#     setuptools-80.10.2         |  py310h06a4308_0         1.3 MB
#     sqlite-3.51.1              |       h3e8d24a_1         1.2 MB
#     tk-8.6.15                  |       h54e0aa7_0         3.4 MB
#     tzdata-2026a               |       he532380_0         117 KB
#     wheel-0.46.3               |  py310h06a4308_0          54 KB
#     xorg-libx11-1.8.12         |       h9b100fa_1         895 KB
#     xorg-libxau-1.0.12         |       h9b100fa_0          13 KB
#     xorg-libxdmcp-1.1.5        |       h9b100fa_0          19 KB
#     xorg-xorgproto-2024.1      |       h5eee18b_1         580 KB
#     xz-5.8.2                   |       h448239c_0         621 KB
#     zlib-1.3.1                 |       hb25bd0a_0          96 KB
#     ------------------------------------------------------------
#                                            Total:        47.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-1_gnu
#   bzip2              pkgs/main/linux-64::bzip2-1.0.8-h5eee18b_6
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2025.12.2-h06a4308_0
#   expat              pkgs/main/linux-64::expat-2.7.4-h7354ed3_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.44-h153f514_2
#   libexpat           pkgs/main/linux-64::libexpat-2.7.4-h7354ed3_0
#   libffi             pkgs/main/linux-64::libffi-3.4.4-h6a678d5_1
#   libgcc             pkgs/main/linux-64::libgcc-15.2.0-h69a1729_7
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-15.2.0-h166f726_7
#   libgomp            pkgs/main/linux-64::libgomp-15.2.0-h4751f2c_7
#   libnsl             pkgs/main/linux-64::libnsl-2.0.0-h5eee18b_0
#   libstdcxx          pkgs/main/linux-64::libstdcxx-15.2.0-h39759b7_7
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-15.2.0-hc03a8fd_7
#   libuuid            pkgs/main/linux-64::libuuid-1.41.5-h5eee18b_0
#   libxcb             pkgs/main/linux-64::libxcb-1.17.0-h9b100fa_0
#   libzlib            pkgs/main/linux-64::libzlib-1.3.1-hb25bd0a_0
#   ncurses            pkgs/main/linux-64::ncurses-6.5-h7934f7d_0
#   openssl            pkgs/main/linux-64::openssl-3.5.5-h1b28b03_0
#   packaging          pkgs/main/linux-64::packaging-25.0-py310h06a4308_1
#   pip                pkgs/main/noarch::pip-26.0.1-pyhc872135_0
#   pthread-stubs      pkgs/main/linux-64::pthread-stubs-0.3-h0ce48e5_1
#   python             pkgs/main/linux-64::python-3.10.19-h6fa692b_0
#   readline           pkgs/main/linux-64::readline-8.3-hc2a1206_0
#   setuptools         pkgs/main/linux-64::setuptools-80.10.2-py310h06a4308_0
#   sqlite             pkgs/main/linux-64::sqlite-3.51.1-h3e8d24a_1
#   tk                 pkgs/main/linux-64::tk-8.6.15-h54e0aa7_0
#   tzdata             pkgs/main/noarch::tzdata-2026a-he532380_0
#   wheel              pkgs/main/linux-64::wheel-0.46.3-py310h06a4308_0
#   xorg-libx11        pkgs/main/linux-64::xorg-libx11-1.8.12-h9b100fa_1
#   xorg-libxau        pkgs/main/linux-64::xorg-libxau-1.0.12-h9b100fa_0
#   xorg-libxdmcp      pkgs/main/linux-64::xorg-libxdmcp-1.1.5-h9b100fa_0
#   xorg-xorgproto     pkgs/main/linux-64::xorg-xorgproto-2024.1-h5eee18b_1
#   xz                 pkgs/main/linux-64::xz-5.8.2-h448239c_0
#   zlib               pkgs/main/linux-64::zlib-1.3.1-hb25bd0a_0
#
#
#
# Downloading and Extracting Packages:
# python-3.10.19       | 24.5 MB   | :   0% 0/1 [00:00<?, ?it/s]
# openssl-3.5.5        | 5.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# libstdcxx-15.2.0     | 3.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# tk-8.6.15            | 3.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# setuptools-80.10.2   | 1.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# sqlite-3.51.1        | 1.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# pip-26.0.1           | 1.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# ncurses-6.5          | 1.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# xorg-libx11-1.8.12   | 895 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# libgcc-15.2.0        | 806 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 672 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# xz-5.8.2             | 621 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# xorg-xorgproto-2024. | 580 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# readline-8.3         | 471 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgomp-15.2.0       | 436 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 430 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# packaging-25.0       | 164 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 125 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.7.4       | 122 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.19       | 24.5 MB   | :   0% 0.0012773650852321932/1 [00:00<01:18, 78.29s/it]
# openssl-3.5.5        | 5.5 MB    | :   1% 0.014080098780693008/1 [00:00<00:07,  7.35s/it]
#
# libstdcxx-15.2.0     | 3.7 MB    | :   0% 0.004197083610957196/1 [00:00<00:24, 25.09s/it]
#
#
# tk-8.6.15            | 3.4 MB    | :   2% 0.0181531064508954/1 [00:00<00:05,  5.85s/it]
#
#
#
# python-3.10.19       | 24.5 MB   | :  18% 0.17755374684727485/1 [00:00<00:00,  1.02it/s]
# python-3.10.19       | 24.5 MB   | :  37% 0.3685198270894877/1 [00:00<00:00,  1.41it/s]
#
#
#
#
# sqlite-3.51.1        | 1.2 MB    | :   1% 0.012953877901161849/1 [00:00<00:23, 24.01s/it]
#
#
#
#
#
# pip-26.0.1           | 1.1 MB    | :   1% 0.013870581313150554/1 [00:00<00:25, 25.85s/it]
#
#
#
#
#
#
# python-3.10.19       | 24.5 MB   | :  51% 0.5096686690076451/1 [00:00<00:00,  1.32it/s]
#
#
#
#
#
#
#
# xorg-libx11-1.8.12   | 895 KB    | :   2% 0.017882324178246957/1 [00:00<00:23, 24.24s/it]
#
#
#
#
#
#
#
#
# libgcc-15.2.0        | 806 KB    | :   2% 0.019857372097871247/1 [00:00<00:23, 24.02s/it]
#
#
#
#
#
#
#
#
#
# python-3.10.19       | 24.5 MB   | :  74% 0.7357622890937432/1 [00:00<00:00,  1.63it/s]
#
#
#
#
#
#
#
#
#
#
# xz-5.8.2             | 621 KB    | :   3% 0.02577535294802453/1 [00:00<00:19, 19.91s/it]
#
#
#
#
#
#
#
#
#
#
#
# xorg-xorgproto-2024. | 580 KB    | :   3% 0.02757436782092818/1 [00:00<00:19, 19.97s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# readline-8.3         | 471 KB    | :   3% 0.03400397653924861/1 [00:00<00:16, 16.99s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.19       | 24.5 MB   | :  90% 0.9011810676313122/1 [00:00<00:00,  1.62it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgomp-15.2.0       | 436 KB    | :   4% 0.03672035913515306/1 [00:00<00:16, 16.86s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# packaging-25.0       | 164 KB    | :  10% 0.09754238902648124/1 [00:00<00:06,  6.71s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 125 KB    | :  13% 0.1275873347142835/1 [00:00<00:04,  5.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.7.4       | 122 KB    | :  13% 0.13110661214560643/1 [00:00<00:04,  5.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# tk-8.6.15            | 3.4 MB    | : 100% 1.0/1 [00:01<00:00,  1.06s/it]
#
#
# tk-8.6.15            | 3.4 MB    | : 100% 1.0/1 [00:01<00:00,  1.06s/it]
#
#
#
# setuptools-80.10.2   | 1.3 MB    | : 100% 1.0/1 [00:01<00:00,  1.18s/it]
#
#
#
# setuptools-80.10.2   | 1.3 MB    | : 100% 1.0/1 [00:01<00:00,  1.18s/it]
#
# libstdcxx-15.2.0     | 3.7 MB    | : 100% 1.0/1 [00:01<00:00,  1.21s/it]
#
# libstdcxx-15.2.0     | 3.7 MB    | : 100% 1.0/1 [00:01<00:00,  1.21s/it]
#
#
#
#
# sqlite-3.51.1        | 1.2 MB    | : 100% 1.0/1 [00:01<00:00,  1.18s/it]
#
#
#
#
# sqlite-3.51.1        | 1.2 MB    | : 100% 1.0/1 [00:01<00:00,  1.18s/it]
# openssl-3.5.5        | 5.5 MB    | : 100% 1.0/1 [00:01<00:00,  4.77it/s]
#
#
#
#
#
# pip-26.0.1           | 1.1 MB    | : 100% 1.0/1 [00:01<00:00,  1.85s/it]
#
#
#
#
#
# pip-26.0.1           | 1.1 MB    | : 100% 1.0/1 [00:01<00:00,  1.85s/it]
#
#
#
#
#
#
#
# xorg-libx11-1.8.12   | 895 KB    | : 100% 1.0/1 [00:02<00:00,  2.01s/it]
#
#
#
#
#
#
#
# xorg-libx11-1.8.12   | 895 KB    | : 100% 1.0/1 [00:02<00:00,  2.01s/it]
#
#
#
#
#
#
#
#
# libgcc-15.2.0        | 806 KB    | : 100% 1.0/1 [00:02<00:00,  2.07s/it]
#
#
#
#
#
#
#
#
# libgcc-15.2.0        | 806 KB    | : 100% 1.0/1 [00:02<00:00,  2.07s/it]
#
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 672 KB    | : 100% 1.0/1 [00:02<00:00,  2.12s/it]
#
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 672 KB    | : 100% 1.0/1 [00:02<00:00,  2.12s/it]
#
#
#
#
#
#
#
#
#
#
# xz-5.8.2             | 621 KB    | : 100% 1.0/1 [00:02<00:00,  2.32s/it]
#
#
#
#
#
#
#
#
#
#
# xz-5.8.2             | 621 KB    | : 100% 1.0/1 [00:02<00:00,  2.32s/it]
#
#
#
#
#
#
#
#
#
#
#
# xorg-xorgproto-2024. | 580 KB    | : 100% 1.0/1 [00:02<00:00,  2.55s/it]
#
#
#
#
#
#
#
#
#
#
#
# xorg-xorgproto-2024. | 580 KB    | : 100% 1.0/1 [00:02<00:00,  2.55s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# readline-8.3         | 471 KB    | : 100% 1.0/1 [00:02<00:00,  2.60s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# readline-8.3         | 471 KB    | : 100% 1.0/1 [00:02<00:00,  2.60s/it]
#
#
#
#
#
#
# ncurses-6.5          | 1.1 MB    | : 100% 1.0/1 [00:02<00:00,  2.75s/it]
#
#
#
#
#
#
# ncurses-6.5          | 1.1 MB    | : 100% 1.0/1 [00:02<00:00,  2.75s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 430 KB    | : 100% 1.0/1 [00:02<00:00,  2.71s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 430 KB    | : 100% 1.0/1 [00:02<00:00,  2.71s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgomp-15.2.0       | 436 KB    | : 100% 1.0/1 [00:02<00:00,  2.74s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgomp-15.2.0       | 436 KB    | : 100% 1.0/1 [00:02<00:00,  2.74s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 125 KB    | : 100% 1.0/1 [00:02<00:00,  2.82s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 125 KB    | : 100% 1.0/1 [00:02<00:00,  2.82s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.7.4       | 122 KB    | : 100% 1.0/1 [00:02<00:00,  2.84s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.7.4       | 122 KB    | : 100% 1.0/1 [00:02<00:00,  2.84s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# packaging-25.0       | 164 KB    | : 100% 1.0/1 [00:02<00:00,  2.84s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# packaging-25.0       | 164 KB    | : 100% 1.0/1 [00:02<00:00,  2.84s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.19       | 24.5 MB   | : 100% 1.0/1 [00:04<00:00,  1.62it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate GPTSoVITS
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# Collecting ipykernel
#   Downloading ipykernel-7.2.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting comm>=0.1.1 (from ipykernel)
#   Downloading comm-0.2.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting debugpy>=1.6.5 (from ipykernel)
#   Downloading debugpy-1.8.20-cp310-cp310-manylinux_2_34_x86_64.whl.metadata (1.4 kB)
# Collecting ipython>=7.23.1 (from ipykernel)
#   Downloading ipython-8.38.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting jupyter-client>=8.8.0 (from ipykernel)
#   Downloading jupyter_client-8.8.0-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupyter-core!=6.0.*,>=5.1 (from ipykernel)
#   Downloading jupyter_core-5.9.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting matplotlib-inline>=0.1 (from ipykernel)
#   Downloading matplotlib_inline-0.2.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting nest-asyncio>=1.4 (from ipykernel)
#   Downloading nest_asyncio-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: packaging>=22 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from ipykernel) (25.0)
# Collecting psutil>=5.7 (from ipykernel)
#   Downloading psutil-7.2.2-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Collecting pyzmq>=25 (from ipykernel)
#   Downloading pyzmq-27.1.0-cp310-cp310-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (6.0 kB)
# Collecting tornado>=6.4.1 (from ipykernel)
#   Downloading tornado-6.5.4-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.8 kB)
# Collecting traitlets>=5.4.0 (from ipykernel)
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting decorator (from ipython>=7.23.1->ipykernel)
#   Downloading decorator-5.2.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting exceptiongroup (from ipython>=7.23.1->ipykernel)
#   Downloading exceptiongroup-1.3.1-py3-none-any.whl.metadata (6.7 kB)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting pexpect>4.3 (from ipython>=7.23.1->ipykernel)
#   Downloading pexpect-4.9.0-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting prompt_toolkit<3.1.0,>=3.0.41 (from ipython>=7.23.1->ipykernel)
#   Downloading prompt_toolkit-3.0.52-py3-none-any.whl.metadata (6.4 kB)
# Collecting pygments>=2.4.0 (from ipython>=7.23.1->ipykernel)
#   Downloading pygments-2.19.2-py3-none-any.whl.metadata (2.5 kB)
# Collecting stack_data (from ipython>=7.23.1->ipykernel)
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting typing_extensions>=4.6 (from ipython>=7.23.1->ipykernel)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting wcwidth (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel)
#   Downloading wcwidth-0.6.0-py3-none-any.whl.metadata (30 kB)
# Collecting parso<0.9.0,>=0.8.4 (from jedi>=0.16->ipython>=7.23.1->ipykernel)
#   Downloading parso-0.8.6-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting python-dateutil>=2.8.2 (from jupyter-client>=8.8.0->ipykernel)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting platformdirs>=2.5 (from jupyter-core!=6.0.*,>=5.1->ipykernel)
#   Downloading platformdirs-4.9.4-py3-none-any.whl.metadata (4.7 kB)
# Collecting ptyprocess>=0.5 (from pexpect>4.3->ipython>=7.23.1->ipykernel)
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->jupyter-client>=8.8.0->ipykernel)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting executing>=1.2.0 (from stack_data->ipython>=7.23.1->ipykernel)
#   Downloading executing-2.2.1-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack_data->ipython>=7.23.1->ipykernel)
#   Downloading asttokens-3.0.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting pure-eval (from stack_data->ipython>=7.23.1->ipykernel)
#   Downloading pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Downloading ipykernel-7.2.0-py3-none-any.whl (118 kB)
# Downloading comm-0.2.3-py3-none-any.whl (7.3 kB)
# Downloading debugpy-1.8.20-cp310-cp310-manylinux_2_34_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 80.7 MB/s  0:00:00
# Downloading ipython-8.38.0-py3-none-any.whl (831 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 831.8/831.8 kB 53.3 MB/s  0:00:00
# Downloading prompt_toolkit-3.0.52-py3-none-any.whl (391 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 93.3 MB/s  0:00:00
# Downloading parso-0.8.6-py2.py3-none-any.whl (106 kB)
# Downloading jupyter_client-8.8.0-py3-none-any.whl (107 kB)
# Downloading jupyter_core-5.9.1-py3-none-any.whl (29 kB)
# Downloading matplotlib_inline-0.2.1-py3-none-any.whl (9.5 kB)
# Downloading nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Downloading pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
# Downloading platformdirs-4.9.4-py3-none-any.whl (21 kB)
# Downloading psutil-7.2.2-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl (155 kB)
# Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Downloading pygments-2.19.2-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 81.0 MB/s  0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading pyzmq-27.1.0-cp310-cp310-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (854 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 854.1/854.1 kB 55.3 MB/s  0:00:00
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading tornado-6.5.4-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (445 kB)
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Downloading exceptiongroup-1.3.1-py3-none-any.whl (16 kB)
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading asttokens-3.0.1-py3-none-any.whl (27 kB)
# Downloading executing-2.2.1-py2.py3-none-any.whl (28 kB)
# Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Downloading wcwidth-0.6.0-py3-none-any.whl (94 kB)
# Installing collected packages: pure-eval, ptyprocess, wcwidth, typing_extensions, traitlets, tornado, six, pyzmq, pygments, psutil, platformdirs, pexpect, parso, nest-asyncio, executing, decorator, debugpy, comm, asttokens, stack_data, python-dateutil, prompt_toolkit, matplotlib-inline, jupyter-core, jedi, exceptiongroup, jupyter-client, ipython, ipykernel
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29/29 [ipykernel]
# Successfully installed asttokens-3.0.1 comm-0.2.3 debugpy-1.8.20 decorator-5.2.1 exceptiongroup-1.3.1 executing-2.2.1 ipykernel-7.2.0 ipython-8.38.0 jedi-0.19.2 jupyter-client-8.8.0 jupyter-core-5.9.1 matplotlib-inline-0.2.1 nest-asyncio-1.6.0 parso-0.8.6 pexpect-4.9.0 platformdirs-4.9.4 prompt_toolkit-3.0.52 psutil-7.2.2 ptyprocess-0.7.0 pure-eval-0.2.3 pygments-2.19.2 python-dateutil-2.9.0.post0 pyzmq-27.1.0 six-1.17.0 stack_data-0.6.3 tornado-6.5.4 traitlets-5.14.3 typing_extensions-4.15.0 wcwidth-0.6.0
# [INFO]: Detected system: Linux 6.6.113+ x86_64
# [INFO]: Detected GCC Version: 11
# [INFO]: Skip Installing GCC & G++ From Conda-Forge
# [INFO]: Installing libstdcxx-ng From Conda-Forge
# [SUCCESS]: libstdcxx-ng=11 Installed...
# [INFO]: Installing FFmpeg & CMake...
# [SUCCESS]: FFmpeg & CMake Installed
# [INFO]: Installing unzip...
# [SUCCESS]: unzip Installed
# [INFO]: Download Model From HuggingFace
# [INFO]: Downloading Pretrained Models...
# pretrained_models.z 100%[===================>]   4.25G   163MB/s    in 15m 3s
# [SUCCESS]: Pretrained Models Downloaded
# [INFO]: Downloading G2PWModel..
# G2PWModel.zip       100%[===================>] 561.58M   155MB/s    in 4.4s
# [SUCCESS]: G2PWModel Downloaded
# [INFO]: Downloading UVR5 Models...
# uvr5_weights.zip    100%[===================>] 498.70M   124MB/s    in 4.0s
# [SUCCESS]: UVR5 Models Downloaded
# [INFO]: Checking For Nvidia Driver Installation...
# \033[INFO]: \033Nvidia Driver Founded
# [INFO]: Installing PyTorch For CUDA 12.6...
# [SUCCESS]: PyTorch Installed
# [INFO]: Installing Python Dependencies From requirements.txt...
# [SUCCESS]: Python Dependencies Installed
# [INFO]: Downloading NLTK Data...
# nltk_data.zip       100%[===================>]   9.46M  14.0MB/s    in 0.7s
# [SUCCESS]: NLTK Data Downloaded
# [INFO]: Downloading Open JTalk Dict...
# open_jtalk_dic_utf_ 100%[===================>]  22.55M  38.9MB/s    in 0.6s
# [SUCCESS]: Open JTalk Dic Downloaded
# [SUCCESS]: Installation Completed

# %% [markdown]
# ## Launch WebUI
# ## 启动 WebUI

# %%
# !cd /content/GPT-SoVITS && source activate GPTSoVITS && export is_share=True && python webui.py
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Running on local URL:  http://0.0.0.0:9874
# Running on public URL: https://3c43baf61e5e62f247.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# "/usr/local/envs/GPTSoVITS/bin/python" -s GPT_SoVITS/inference_webui.py "Auto"
# /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/jieba/_compat.py:18: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.0.1)/charset_normalizer (3.4.5) doesn't match a supported version!
#   warnings.warn(
# GPT_SoVITS/pretrained_models/v2Pro/s2Gv2Pro.pth v2 v2Pro False
# loading sovits_v2Pro <All keys matched successfully>
# Running on local URL:  http://0.0.0.0:9872
# Running on public URL: https://ff06ed9ea68ffcc0b0.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# Actual Input Reference Text: 神様、お守りください。
# Actual Input Target Text: あっ……また、別のアプリを開こうとしたね？
# どうして……？ わたしずっと、ここで待ってるのに……。
# ふふっ……。もう、画面から目を逸らしちゃ……ダメだからね。
# Traceback (most recent call last):
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/gradio/queueing.py", line 536, in process_events
#     response = await route_utils.call_process_api(
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/gradio/route_utils.py", line 322, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/gradio/blocks.py", line 1935, in process_api
#     result = await self.call_function(
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/gradio/blocks.py", line 1532, in call_function
#     prediction = await utils.async_iteration(iterator)
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/gradio/utils.py", line 671, in async_iteration
#     return await iterator.__anext__()
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/gradio/utils.py", line 664, in __anext__
#     return await anyio.to_thread.run_sync(
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/anyio/to_thread.py", line 63, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 2502, in run_sync_in_worker_thread
#     return await future
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 986, in run
#     result = context.run(func, *args)
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/gradio/utils.py", line 647, in run_sync_iterator_async
#     return next(iterator)
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/gradio/utils.py", line 809, in gen_wrapper
#     response = next(iterator)
#   File "/content/GPT-SoVITS/GPT_SoVITS/inference_webui.py", line 816, in get_tts_wav
#     raise OSError(i18n("参考音频在3~10秒范围外，请更换！"))
# OSError: Reference audio is outside the 3-10 second range, please choose another one!
# Actual Input Reference Text: みなさんお疲れ様でした。おめでとうございます。おめでとう。頑張ったね。優勝おめでとう。
# Actual Input Target Text: あっ……また、別のアプリを開こうとしたね？
# どうして……？ わたしずっと、ここで待ってるのに……。
# ふふっ……。もう、画面から目を逸らしちゃ……ダメだからね。
# Actual Input Target Text (after sentence segmentation): あっ…
# また、
# 別のアプリを開こうとしたね？
# どうして…
#  わたしずっと、
# ここで待ってるのに…
# ふふっ…
# もう、
# 画面から目を逸らしちゃ…
# ダメだからね。
# ['みなさんお疲れ様でした。おめでとうございます。おめでとう。頑張ったね。優勝おめでとう。']
# ['ja']
# reading /content/GPT-SoVITS/GPT_SoVITS/text/ja_userdic/userdict.csv ... 134201
# emitting double-array: 100% |###########################################|
#
# done!
# Actual Input Target Text (per sentence): あっ…また、。
# ['あっ…また、。']
# ['ja']
# Processed text from the frontend (per sentence): あっ…また、。
#   3% 48/1500 [00:00<00:25, 56.04it/s]
# Actual Input Target Text (per sentence): 別のアプリを開こうとしたね？
# ['別のアプリを開こうとしたね？']
# ['ja']
# Processed text from the frontend (per sentence): 別のアプリを開こうとしたね？
#   4% 57/1500 [00:00<00:13, 106.71it/s]
# Actual Input Target Text (per sentence): どうして…
# ['どうして…']
# ['ja']
# Processed text from the frontend (per sentence): どうして…
#   2% 26/1500 [00:00<00:20, 73.68it/s]
# Actual Input Target Text (per sentence):  わたしずっと、。
# ['わたしずっと、。']
# ['ja']
# Processed text from the frontend (per sentence): わたしずっと、。
#   2% 34/1500 [00:00<00:19, 76.85it/s]
# Actual Input Target Text (per sentence): ここで待ってるのに…
# ['ここで待ってるのに…']
# ['ja']
# Processed text from the frontend (per sentence): ここで待ってるのに…
#   3% 46/1500 [00:00<00:20, 71.11it/s]
# Actual Input Target Text (per sentence): ふふっ…もう、。
# ['ふふっ…もう、。']
# ['ja']
# Processed text from the frontend (per sentence): ふふっ…もう、。
#   5% 78/1500 [00:00<00:14, 95.98it/s]
# Actual Input Target Text (per sentence): 画面から目を逸らしちゃ…
# ['画面から目を逸らしちゃ…']
# ['ja']
# Processed text from the frontend (per sentence): 画面から目を逸らしちゃ…
#   4% 55/1500 [00:00<00:14, 102.94it/s]
# Actual Input Target Text (per sentence): ダメだからね。
# ['ダメだからね。']
# ['ja']
# Processed text from the frontend (per sentence): ダメだからね。
#   2% 29/1500 [00:00<00:14, 102.98it/s]
# 1.836	1.474	4.495	4.552
# Actual Input Reference Text: みなさんお疲れ様でした。おめでとうございます。おめでとう。頑張ったね。優勝おめでとう。
# Actual Input Target Text: えー？本当に？そんなことある？
# いやいや、ちょっと信じられないんだけど。
# まあ…でも、なんか面白いね。ははは！
# Actual Input Target Text (after sentence segmentation): えー？
# 本当に？
# そんなことある？
# いやいや、
# ちょっと信じられないんだけど。
# まあ…
# でも、
# なんか面白いね。
# ははは！
# ['みなさんお疲れ様でした。おめでとうございます。おめでとう。頑張ったね。優勝おめでとう。']
# ['ja']
# Actual Input Target Text (per sentence): えー？本当に？
# ['えー？本当に？']
# ['ja']
# Processed text from the frontend (per sentence): えー？本当に？
#   6% 86/1500 [00:00<00:13, 104.14it/s]
# Actual Input Target Text (per sentence): そんなことある？
# ['そんなことある？']
# ['ja']
# Processed text from the frontend (per sentence): そんなことある？
#   3% 40/1500 [00:00<00:13, 106.60it/s]
# Actual Input Target Text (per sentence): いやいや、。
# ['いやいや、。']
# ['ja']
# Processed text from the frontend (per sentence): いやいや、。
#   2% 24/1500 [00:00<00:14, 102.88it/s]
# Actual Input Target Text (per sentence): ちょっと信じられないんだけど。
# ['ちょっと信じられないんだけど。']
# ['ja']
# Processed text from the frontend (per sentence): ちょっと信じられないんだけど。
#   3% 50/1500 [00:00<00:13, 106.03it/s]
# Actual Input Target Text (per sentence): まあ…でも、。
# ['まあ…でも、。']
# ['ja']
# Processed text from the frontend (per sentence): まあ…でも、。
#   4% 66/1500 [00:00<00:13, 107.30it/s]
# Actual Input Target Text (per sentence): なんか面白いね。ははは！
# ['なんか面白いね。ははは！']
# ['ja']
# Processed text from the frontend (per sentence): なんか面白いね。ははは！
#   4% 67/1500 [00:00<00:13, 107.93it/s]
# 0.038	0.029	3.156	1.362

# %%
# !/usr/local/envs/GPTSoVITS/bin/pip install torch==2.5.1 torchvision==0.20.1 torchaudio==2.5.1 --index-url https://download.pytorch.org/whl/cu124
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Looking in indexes: https://download.pytorch.org/whl/cu124
# Collecting torch==2.5.1
#   Downloading https://download.pytorch.org/whl/cu124/torch-2.5.1%2Bcu124-cp310-cp310-linux_x86_64.whl (908.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 MB 29.0 MB/s  0:00:13
# Collecting torchvision==0.20.1
#   Downloading https://download.pytorch.org/whl/cu124/torchvision-0.20.1%2Bcu124-cp310-cp310-linux_x86_64.whl (7.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 74.9 MB/s  0:00:00
# Collecting torchaudio==2.5.1
#   Downloading https://download.pytorch.org/whl/cu124/torchaudio-2.5.1%2Bcu124-cp310-cp310-linux_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 93.6 MB/s  0:00:00
# Requirement already satisfied: filelock in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from torch==2.5.1) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from torch==2.5.1) (4.15.0)
# Requirement already satisfied: networkx in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from torch==2.5.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from torch==2.5.1) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from torch==2.5.1) (2025.12.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch==2.5.1)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 144.2 MB/s  0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch==2.5.1)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.8 MB/s  0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch==2.5.1)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 153.1 MB/s  0:00:00
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch==2.5.1)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 44.9 MB/s  0:00:10
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch==2.5.1)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 58.8 MB/s  0:00:04
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch==2.5.1)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 74.2 MB/s  0:00:02
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch==2.5.1)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 67.3 MB/s  0:00:00
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch==2.5.1)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 69.7 MB/s  0:00:01
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch==2.5.1)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 31.4 MB/s  0:00:06
# Collecting nvidia-nccl-cu12==2.21.5 (from torch==2.5.1)
#   Downloading https://download.pytorch.org/whl/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 72.0 MB/s  0:00:02
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch==2.5.1)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch==2.5.1)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 140.3 MB/s  0:00:00
# Collecting triton==3.1.0 (from torch==2.5.1)
#   Downloading https://download.pytorch.org/whl/triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 68.7 MB/s  0:00:03
# Collecting sympy==1.13.1 (from torch==2.5.1)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from torchvision==0.20.1) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from torchvision==0.20.1) (10.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from sympy==1.13.1->torch==2.5.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages (from jinja2->torch==2.5.1) (2.1.5)
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 115.7 MB/s  0:00:00
# Installing collected packages: triton, sympy, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, torchvision, torchaudio
#   Attempting uninstall: triton
#     Found existing installation: triton 3.6.0
#     Uninstalling triton-3.6.0:
#       Successfully uninstalled triton-3.6.0
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.14.0
#     Uninstalling sympy-1.14.0:
#       Successfully uninstalled sympy-1.14.0
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.6.77
#     Uninstalling nvidia-nvtx-cu12-12.6.77:
#       Successfully uninstalled nvidia-nvtx-cu12-12.6.77
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.6.85
#     Uninstalling nvidia-nvjitlink-cu12-12.6.85:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.6.85
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.27.5
#     Uninstalling nvidia-nccl-cu12-2.27.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.27.5
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.7.77
#     Uninstalling nvidia-curand-cu12-10.3.7.77:
#       Successfully uninstalled nvidia-curand-cu12-10.3.7.77
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.0.4
#     Uninstalling nvidia-cufft-cu12-11.3.0.4:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.0.4
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.6.77
#     Uninstalling nvidia-cuda-runtime-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.6.77
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.6.80
#     Uninstalling nvidia-cuda-cupti-cu12-12.6.80:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.6.80
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.6.4.1
#     Uninstalling nvidia-cublas-cu12-12.6.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.6.4.1
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.4.2
#     Uninstalling nvidia-cusparse-cu12-12.5.4.2:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.4.2
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.10.2.21
#     Uninstalling nvidia-cudnn-cu12-9.10.2.21:
#       Successfully uninstalled nvidia-cudnn-cu12-9.10.2.21
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━ 12/17 [nvidia-cudnn-cu12]

# %%
from google.colab import drive
drive.mount('/content/drive')
